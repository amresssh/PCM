# %%
import pandas as pd
import glob

# %%
files = glob.glob('*.csv')

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
len(dfs)
# Out:
# 12

# %%
dfs
# Out:
# [                                                                                                                                                                                                                                                                   1  \
#  Date/Time           [1] Site Diffuse Solar Radiation Rate per Area ... [1] Site Direct Solar Radiation Rate per Area  ... [1] Site Outdoor Air Drybulb Temperature  (C) [1] Surface Inside Face Conduction Heat Transfe...  [1] Surface Inside Face Temperature  (C)
#  NaN                 Environment                                        Environment                                        Environment                                   BLOCK1:ZONE1_WALL_3_0_0                                              BLOCK1:ZONE1_WALL_3_0_0
# ...
